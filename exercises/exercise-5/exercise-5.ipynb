# %%
import pandas as pd
import numpy as np

from scipy import sparse
from scipy.sparse import csr_matrix
# from sparselsh import LSH
# from surprise import SVD

# %%
df = pd.read_csv("../../data/restaurants/google_restaurant_ratings.csv")
df.head()
df.size
# Out:
# 490140

# %%
df_training = df[df["test"] == 0]
df_testing = df[df["test"] == 1]
print(df_training.size + df_testing.size)
# Out:
# 490140

# %%
# Out:
# 55075
